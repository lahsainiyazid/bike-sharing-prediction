# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import sklearn

# %% [markdown]
# I have decided to work on the hourly dataset :

# %%
df=pd.read_csv('/home/yazid/sklearn/bikes/data/hour.csv')

# %%
df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
len(df)
# Out:
# 17379

# %%
df.drop('instant',axis=1,inplace=True)

# %%
df['dteday']=pd.to_datetime(df['dteday'])

# %% [markdown]
# Let's create some features :

# %% [markdown]
# Cyclical temporical features :

# %%
df['hr_sin']=np.sin(2*np.pi*(df['hr']/24))
df['hr_cos']=np.cos(2*np.pi*(df['hr']/24))
df['mnth_sin']=np.sin(2*np.pi*(df['mnth']/12))
df['mnth_cos']=np.cos(2*np.pi*(df['mnth']/12))
df['week_sin']=np.sin(2*np.pi*(df['weekday']/7))
df['week_cos']=np.cos(2*np.pi*(df['weekday']/7))

# %% [markdown]
# Commute features :

# %%
df['Rush_Hour']=((df['workingday']==1)&(df['hr'].isin([7,8,9,17,18,19]))).astype(bool)
df['Off_Peak']=(df['hr'].isin([0,1,2,3,4,5])).astype(bool)

# %%
df['Previous_hour_cnt']=df['cnt'].shift(1)
df['Previous_day_cnt']=df['cnt'].shift(24)

# %% [markdown]
# We create now weather based columns :

# %%
df['delta_temp']=df['temp']-df['atemp']
df['temp*hum']=df['temp']*df['hum']
df['bad_weather']=(df['weathersit']>=3).astype(bool)
df['windspeed*temp']=(df['temp']*df['windspeed'])

# %%
X=df.drop(['cnt','casual','registered'],axis=1)
y=df['cnt']
X_train=X[:13903]
X_test=X[13903:]
y_train=y[:13903]
y_test=y[13903:]

# %%
from sklearn.ensemble import RandomForestRegressor 
v0=RandomForestRegressor()
v0.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# DTypePromotionError                       Traceback (most recent call last)
# Cell In[18], line 3
#       1 from sklearn.ensemble import RandomForestRegressor
#       2 v0=RandomForestRegressor()
# ----> 3 v0.fit(X_train,y_train)
#
# File ~/sklearn/.venv/lib64/python3.14/site-packages/sklearn/base.py:1403, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1393     estimator._validate_params()
#    1395 with (
#    1396     config_context(
#    1397         skip_parameter_validation=(
#    (...)   1401     callback_management_context(estimator),
#    1402 ):
# -> 1403     return fit_method(estimator, *args, **kwargs)
#
# File ~/sklearn/.venv/lib64/python3.14/site-packages/sklearn/ensemble/_forest.py:334, in BaseForest.fit(self, X, y, sample_weight)
#     331 if issparse(y):
#     332     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 334 X, y = validate_data(
#     335     self,
#     336     X,
#     337     y,
#     338     multi_output=True,
#     339     accept_sparse="csc",
#     340     dtype=np.float32,
#     341     ensure_all_finite=False,
#     342 )
#     343 # _compute_missing_values_in_feature_mask checks if X has missing values and
#     344 # will raise an error if the underlying tree base estimator can't handle missing
#     345 # values. Only the criterion is required to determine if the tree supports
#     346 # missing values.
#     347 estimator = type(self.estimator)(criterion=self.criterion)
#
# File ~/sklearn/.venv/lib64/python3.14/site-packages/sklearn/utils/validation.py:3055, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    3053         y = check_array(y, input_name="y", **check_y_params)
#    3054     else:
# -> 3055         X, y = check_X_y(X, y, **check_params)
#    3056     out = X, y
#    3058 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~/sklearn/.venv/lib64/python3.14/site-packages/sklearn/utils/validation.py:1327, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1322         estimator_name = _check_estimator_name(estimator)
#    1323     raise ValueError(
#    1324         f"{estimator_name} requires y to be passed, but the target y is None"
#    1325     )
# -> 1327 X = check_array(
#    1328     X,
#    1329     accept_sparse=accept_sparse,
#    1330     accept_large_sparse=accept_large_sparse,
#    1331     dtype=dtype,
#    1332     order=order,
#    1333     copy=copy,
#    1334     force_writeable=force_writeable,
#    1335     ensure_all_finite=ensure_all_finite,
#    1336     ensure_2d=ensure_2d,
#    1337     allow_nd=allow_nd,
#    1338     ensure_min_samples=ensure_min_samples,
#    1339     ensure_min_features=ensure_min_features,
#    1340     estimator=estimator,
#    1341     input_name="X",
#    1342 )
#    1344 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1346 check_consistent_length(X, y)
#
# File ~/sklearn/.venv/lib64/python3.14/site-packages/sklearn/utils/validation.py:922, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     920 has_pandas_string = any(_is_pandas_string_dtype(d) for d in dtypes_orig)
#     921 if all(isinstance(dtype_iter, np.dtype) for dtype_iter in dtypes_orig):
# --> 922     dtype_orig = np.result_type(*dtypes_orig)
#     923 elif has_pandas_string:
#     924     # Force object if any of the dtypes is a StringDtype.
#     925     dtype_orig = object
#
# DTypePromotionError: The DType <class 'numpy.dtypes.DateTime64DType'> could not be promoted by <class 'numpy.dtypes.Float64DType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy.dtypes.DateTime64DType'>, <class 'numpy.dtypes.Int64DType'>, <class 'numpy.dtypes.Int64DType'>, <class 'numpy.dtypes.Int64DType'>, <class 'numpy.dtypes.Int64DType'>, <class 'numpy.dtypes.Int64DType'>, <class 'numpy.dtypes.Int64DType'>, <class 'numpy.dtypes.Int64DType'>, <class 'numpy.dtypes.Int64DType'>, <class 'numpy.dtypes.Float64DType'>, <class 'numpy.dtypes.Float64DType'>, <class 'numpy.dtypes.Float64DType'>, <class 'numpy.dtypes.Float64DType'>, <class 'numpy.dtypes.Float64DType'>, <class 'numpy.dtypes.Float64DType'>, <class 'numpy.dtypes.Float64DType'>, <class 'numpy.dtypes.Float64DType'>, <class 'numpy.dtypes.Float64DType'>, <class 'numpy.dtypes.Float64DType'>, <class 'numpy.dtypes.BoolDType'>, <class 'numpy.dtypes.BoolDType'>, <class 'numpy.dtypes.Float64DType'>, <class 'numpy.dtypes.Float64DType'>, <class 'numpy.dtypes.Float64DType'>)

# %%
from sklearn.metrics import mean_absolute_error 
y_pred_0=v0.predict(X_test) 
mae_0=mean_absolute_error(y_test,y_pred_0 )
(mae_0 /y_test.median())*100

# %% [markdown]
# Our first model is performing very well let's try to improve things further with RandomizedSearchCV

# %%
from sklearn.model_selection import RandomizedSearchCV 
param_grid={'n_estimators':[300,500,700],
           'min_samples_split':[2,6,8,10],
           'min_samples_leaf':[1,5,10,20],
           'max_features':['log2','sqrt',0.5,0.8]}
randomized_search=RandomizedSearchCV(estimator=v0,cv=5,n_iter=60,param_distributions=param_grid,n_jobs=-1,random_state=42)
randomized_search.fit(X_train,y_train) 
print(randomized_search.best_params_)

# %%
v1=RandomForestRegressor(**randomized_search.best_params_,random_state=42,n_jobs=-1)
v1.fit(X_train,y_train)

# %%
y_pred_1=v1.predict(X_test)
mae_1=mean_absolute_error(y_test,y_pred_1)
(mae_1/y_test.median())*100

# %%
def extract_features(model):
    feature_names=model.feature_names_in_ 
    importances=pd.DataFrame({'Feature':feature_names,
                             'Importance':model.feature_importances_}).sort_values('Importance',ascending=False).reset_index(drop=True)
    return importances

# %%
extract_features(v0)
